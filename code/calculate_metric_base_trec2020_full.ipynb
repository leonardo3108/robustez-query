# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardo3108/robustez-query/blob/main/code/calculate_metric_base_trec2020_full.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparação

# %% [markdown]
# ## Carga dos pacotes pygaggle e pyserini

# %%
# !pip install git+https://github.com/castorini/pygaggle.git
# Out:
# Collecting git+https://github.com/castorini/pygaggle.git
#   Cloning https://github.com/castorini/pygaggle.git to /tmp/pip-req-build-dc96ny72
#   Running command git clone -q https://github.com/castorini/pygaggle.git /tmp/pip-req-build-dc96ny72
#   Running command git submodule update --init --recursive -q
# Collecting coloredlogs==14.0
#   Downloading coloredlogs-14.0-py2.py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.4 MB/s
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from pygaggle==0.0.3.1) (1.19.5)
# Collecting pydantic==1.7.4
#   Downloading pydantic-1.7.4-cp37-cp37m-manylinux2014_x86_64.whl (9.1 MB)
#      |████████████████████████████████| 9.1 MB 10.0 MB/s
# Collecting pyserini>=0.13.0
#   Downloading pyserini-0.14.0-py3-none-any.whl (75.5 MB)
#      |████████████████████████████████| 75.5 MB 6.3 kB/s
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 39.5 MB/s
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 1.5 MB/s
# Collecting spacy==3.0.6
#   Downloading spacy-3.0.6-cp37-cp37m-manylinux2014_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 35.4 MB/s
# Collecting tensorboard==2.5.0
#   Downloading tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 45.4 MB/s
# Collecting tensorflow==2.5.0
#   Downloading tensorflow-2.5.0-cp37-cp37m-manylinux2010_x86_64.whl (454.3 MB)
#      |████████████████████████████████| 454.3 MB 16 kB/s
# Collecting tokenizers==0.10.2
#   Downloading tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 30.7 MB/s
# Collecting tqdm==4.56.0
#   Downloading tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 984 kB/s
# Collecting transformers==4.6.1
#   Downloading transformers-4.6.1-py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 33.6 MB/s
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 40.1 MB/s
# Collecting sentence_transformers==2.0.0
#   Downloading sentence-transformers-2.0.0.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 4.6 MB/s
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from pygaggle==0.0.3.1) (1.10.0+cu111)
# Collecting humanfriendly>=7.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.2 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2->pygaggle==0.0.3.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2->pygaggle==0.0.3.1) (3.0.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers==2.0.0->pygaggle==0.0.3.1) (0.11.1+cu111)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers==2.0.0->pygaggle==0.0.3.1) (3.2.5)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.2 MB/s
# Collecting catalogue<2.1.0,>=2.0.3
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.3 MB/s
# Collecting thinc<8.1.0,>=8.0.3
#   Downloading thinc-8.0.13-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (628 kB)
#      |████████████████████████████████| 628 kB 48.7 MB/s
# Collecting spacy-legacy<3.1.0,>=3.0.4
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (0.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (2.0.6)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (451 kB)
#      |████████████████████████████████| 451 kB 47.0 MB/s
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (0.8.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (3.10.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (3.0.6)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.6->pygaggle==0.0.3.1) (2.23.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (1.42.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (1.8.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (0.12.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (0.37.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.5.0->pygaggle==0.0.3.1) (0.6.1)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0->pygaggle==0.0.3.1) (1.1.2)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0->pygaggle==0.0.3.1) (1.15.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0->pygaggle==0.0.3.1) (0.4.0)
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 38.3 MB/s
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 55.8 MB/s
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0->pygaggle==0.0.3.1) (0.2.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0->pygaggle==0.0.3.1) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0->pygaggle==0.0.3.1) (1.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0->pygaggle==0.0.3.1) (3.3.0)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 45.7 MB/s
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0->pygaggle==0.0.3.1) (3.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1->pygaggle==0.0.3.1) (4.8.2)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 37.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1->pygaggle==0.0.3.1) (2019.12.20)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.0.8-py3-none-any.whl (34 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1->pygaggle==0.0.3.1) (3.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.3->spacy==3.0.6->pygaggle==0.0.3.1) (3.6.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.5.0->pygaggle==0.0.3.1) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.5.0->pygaggle==0.0.3.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.5.0->pygaggle==0.0.3.1) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.5.0->pygaggle==0.0.3.1) (1.3.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow==2.5.0->pygaggle==0.0.3.1) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy==3.0.6->pygaggle==0.0.3.1) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy==3.0.6->pygaggle==0.0.3.1) (5.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard==2.5.0->pygaggle==0.0.3.1) (0.4.8)
# Collecting pyjnius>=1.4.0
#   Downloading pyjnius-1.4.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 32.7 MB/s
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from pyserini>=0.13.0->pygaggle==0.0.3.1) (1.1.5)
# Collecting onnxruntime>=1.8.1
#   Downloading onnxruntime-1.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 50.4 MB/s
# Requirement already satisfied: Cython>=0.29.21 in /usr/local/lib/python3.7/dist-packages (from pyserini>=0.13.0->pygaggle==0.0.3.1) (0.29.24)
# Collecting nmslib>=2.1.1
#   Downloading nmslib-2.1.1-cp37-cp37m-manylinux2010_x86_64.whl (13.5 MB)
#      |████████████████████████████████| 13.5 MB 13.2 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib>=2.1.1->pyserini>=0.13.0->pygaggle==0.0.3.1) (5.4.8)
# Collecting pybind11<2.6.2
#   Downloading pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
#      |████████████████████████████████| 188 kB 49.6 MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->pyserini>=0.13.0->pygaggle==0.0.3.1) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->pyserini>=0.13.0->pygaggle==0.0.3.1) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.6->pygaggle==0.0.3.1) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.6->pygaggle==0.0.3.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.6->pygaggle==0.0.3.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.6->pygaggle==0.0.3.1) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.5.0->pygaggle==0.0.3.1) (3.1.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy==3.0.6->pygaggle==0.0.3.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy==3.0.6->pygaggle==0.0.3.1) (2.0.1)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers==2.0.0->pygaggle==0.0.3.1) (7.1.2)
# Building wheels for collected packages: pygaggle, sentence-transformers, wrapt
#   Building wheel for pygaggle (setup.py) ... done
#   Created wheel for pygaggle: filename=pygaggle-0.0.3.1-py3-none-any.whl size=67744 sha256=924edb28d32f9774cc29a2375245f98dc885c24162af985f054550edb537d5a8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1t2adyuk/wheels/bf/6a/63/cf69ae691ad4b4000e3234b5a7d43cc878140afeeebd46d9e5
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.0.0-py3-none-any.whl size=126710 sha256=765a232bd18f646813acfaf4ab0197dd7a6e83adfd498b44e72d9ce94e2271ea
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/0f/faafd427f705c4b012274ba60d9a91d75830306811e1355293
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68712 sha256=a357a7d7339f239ed1a5bcb78fdaf817ba69f49a60dc567ec3db00a626c10610
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built pygaggle sentence-transformers wrapt
# Installing collected packages: typing-extensions, tqdm, catalogue, typer, tokenizers, srsly, scipy, sacremoses, pydantic, pybind11, huggingface-hub, grpcio, flatbuffers, wrapt, transformers, thinc, tensorflow-estimator, tensorboard, spacy-legacy, sentencepiece, scikit-learn, pyjnius, pathy, onnxruntime, nmslib, keras-nightly, humanfriendly, tensorflow, spacy, sentence-transformers, pyserini, coloredlogs, pygaggle
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.13.3
#     Uninstalling wrapt-1.13.3:
#       Successfully uninstalled wrapt-1.13.3
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.1
#     Uninstalling scikit-learn-1.0.1:
#       Successfully uninstalled scikit-learn-1.0.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed catalogue-2.0.6 coloredlogs-14.0 flatbuffers-1.12 grpcio-1.34.1 huggingface-hub-0.0.8 humanfriendly-10.0 keras-nightly-2.5.0.dev2021032900 nmslib-2.1.1 onnxruntime-1.9.0 pathy-0.6.1 pybind11-2.6.1 pydantic-1.7.4 pygaggle-0.0.3.1 pyjnius-1.4.1 pyserini-0.14.0 sacremoses-0.0.46 scikit-learn-0.24.2 scipy-1.5.4 sentence-transformers-2.0.0 sentencepiece-0.1.95 spacy-3.0.6 spacy-legacy-3.0.8 srsly-2.4.2 tensorboard-2.5.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 thinc-8.0.13 tokenizers-0.10.2 tqdm-4.56.0 transformers-4.6.1 typer-0.3.2 typing-extensions-3.7.4.3 wrapt-1.12.1

# %%
# !pip install pyserini
# Out:
# Requirement already satisfied: pyserini in /usr/local/lib/python3.7/dist-packages (0.14.0)
# Requirement already satisfied: onnxruntime>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from pyserini) (1.9.0)
# Requirement already satisfied: Cython>=0.29.21 in /usr/local/lib/python3.7/dist-packages (from pyserini) (0.29.24)
# Requirement already satisfied: sentencepiece>=0.1.95 in /usr/local/lib/python3.7/dist-packages (from pyserini) (0.1.95)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from pyserini) (1.1.5)
# Requirement already satisfied: transformers>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from pyserini) (4.6.1)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from pyserini) (1.19.5)
# Requirement already satisfied: pyjnius>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from pyserini) (1.4.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from pyserini) (1.5.4)
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.7/dist-packages (from pyserini) (0.24.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pyserini) (4.56.0)
# Requirement already satisfied: nmslib>=2.1.1 in /usr/local/lib/python3.7/dist-packages (from pyserini) (2.1.1)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/lib/python3.7/dist-packages (from nmslib>=2.1.1->pyserini) (2.6.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib>=2.1.1->pyserini) (5.4.8)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=1.8.1->pyserini) (3.17.3)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=1.8.1->pyserini) (1.12)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->pyserini) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->pyserini) (2018.9)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pyjnius>=1.4.0->pyserini) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.1->pyserini) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.1->pyserini) (3.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (21.3)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (0.10.2)
# Requirement already satisfied: huggingface-hub==0.0.8 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (0.0.8)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (4.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (2.23.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (0.0.46)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.6.0->pyserini) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.6.0->pyserini) (3.7.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers>=4.6.0->pyserini) (3.0.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=4.6.0->pyserini) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=4.6.0->pyserini) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=4.6.0->pyserini) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=4.6.0->pyserini) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.6.0->pyserini) (7.1.2)

# %% [markdown]
# ## Carga do pacote Faiss (GPU)

# %%
# !pip install faiss-gpu
# Out:
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.1.post2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89.7 MB)
#      |████████████████████████████████| 89.7 MB 12 kB/s
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.1.post2

# %% [markdown]
# ## Carga do dataset MsMarco Passage

# %%
from pyserini.search import SimpleSearcher

# `SimpleSearcher` defaults to BM25 scoring function.
searcher = SimpleSearcher.from_prebuilt_index('msmarco-passage')
# Out:
# index-msmarco-passage-20201117-f87c94.tar.gz: 0.00B [00:00, ?B/s]
# Attempting to initialize pre-built index msmarco-passage.
# Downloading index at https://rgw.cs.uwaterloo.ca/JIMMYLIN-bucket0/pyserini-indexes/index-msmarco-passage-20201117-f87c94.tar.gz...
# index-msmarco-passage-20201117-f87c94.tar.gz: 2.07GB [01:01, 35.8MB/s]
# Extracting /root/.cache/pyserini/indexes/index-msmarco-passage-20201117-f87c94.tar.gz into /root/.cache/pyserini/indexes/index-msmarco-passage-20201117-f87c94.1efad4f1ae6a77e235042eff4be1612d...
# Initializing msmarco-passage...

# %% [markdown]
# ## Utility library

# %%
# !wget -nc https://raw.githubusercontent.com/leonardo3108/robustez-query/main/code/local/util_bd_dataframe.py
# Out:
# --2021-11-23 00:13:24--  https://raw.githubusercontent.com/leonardo3108/robustez-query/main/code/local/util_bd_dataframe.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11889 (12K) [text/plain]
# Saving to: ‘util_bd_dataframe.py’
#
# util_bd_dataframe.p 100%[===================>]  11.61K  --.-KB/s    in 0s
#
# 2021-11-23 00:13:24 (59.0 MB/s) - ‘util_bd_dataframe.py’ saved [11889/11889]

# %%
# !wget --directory-prefix=/content/data/ -nc https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_original_query.csv
# Out:
# --2021-11-23 00:17:36--  https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_original_query.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3302 (3.2K) [text/plain]
# Saving to: ‘/content/data/tab_original_query.csv’
#
# tab_original_query. 100%[===================>]   3.22K  --.-KB/s    in 0s
#
# 2021-11-23 00:17:36 (34.0 MB/s) - ‘/content/data/tab_original_query.csv’ saved [3302/3302]

# %%
! wget -nc https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_calculated_metric.csv -P data
# Out:
# --2021-11-23 00:42:48--  https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_calculated_metric.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113430 (111K) [text/plain]
# Saving to: ‘data/tab_calculated_metric.csv’
#
# tab_calculated_metr 100%[===================>] 110.77K  --.-KB/s    in 0.01s
#
# 2021-11-23 00:42:48 (7.26 MB/s) - ‘data/tab_calculated_metric.csv’ saved [113430/113430]

# %%
! wget -nc https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_noise_kind.csv -P data
! wget -nc https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_search_context.csv -P data
# Out:
# --2021-11-23 00:20:52--  https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_noise_kind.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 382 [text/plain]
# Saving to: ‘data/tab_noise_kind.csv’
#
# tab_noise_kind.csv  100%[===================>]     382  --.-KB/s    in 0s
#
# 2021-11-23 00:20:52 (16.0 MB/s) - ‘data/tab_noise_kind.csv’ saved [382/382]
#
# --2021-11-23 00:20:52--  https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_search_context.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 488 [text/plain]
# Saving to: ‘data/tab_search_context.csv’
#
# tab_search_context. 100%[===================>]     488  --.-KB/s    in 0s
#
# 2021-11-23 00:20:52 (32.4 MB/s) - ‘data/tab_search_context.csv’ saved [488/488]

# %%
! wget -nc https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_noisy_query.csv -P data
# Out:
# --2021-11-23 00:24:53--  https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/tab_noisy_query.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20537 (20K) [text/plain]
# Saving to: ‘data/tab_noisy_query.csv’
#
# tab_noisy_query.csv 100%[===================>]  20.06K  --.-KB/s    in 0s
#
# 2021-11-23 00:24:53 (115 MB/s) - ‘data/tab_noisy_query.csv’ saved [20537/20537]

# %%
! wget -nc https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/originals/2020qrels-pass.txt -P data/originals
# Out:
# --2021-11-23 00:21:58--  https://raw.githubusercontent.com/leonardo3108/robustez-query/main/data/originals/2020qrels-pass.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 218617 (213K) [text/plain]
# Saving to: ‘data/originals/2020qrels-pass.txt’
#
# 2020qrels-pass.txt  100%[===================>] 213.49K  --.-KB/s    in 0.01s
#
# 2021-11-23 00:21:58 (14.0 MB/s) - ‘data/originals/2020qrels-pass.txt’ saved [218617/218617]

# %%
import util_bd_dataframe as util_bd_pandas

# %% [markdown]
# ## Carga do Reranker MonoT5

# %%
# !nvidia-smi
# Out:
# Tue Nov 23 00:25:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    28W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from pygaggle.rerank.transformer import MonoT5

reranker = MonoT5()
# Out:
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.09k [00:00<?, ?B/s]

# %% [markdown]
# # Execução

# %%
import json
from pygaggle.rerank.base import Query, Text
from pygaggle.rerank.base import hits_to_texts
import math

# %% [markdown]
# ## Cálculo do BM25

# %%
  _, dict_val_idcg10 = util_bd_pandas.read_df_original_query()
  df_noisy_query = util_bd_pandas.read_df_noisy_query()
  dict_judment, _ = util_bd_pandas.load_judment()

  # Calculate dcg10 and ndcg10 of noisy queries
  for noise_kind in df_noisy_query['cod_noise_kind'].unique():
      calculated_metric = {'cod_original_query':[],'dcg10':[],'ndcg10':[], 'qtd_judment_assumed_zero_relevance':[]}
      for index, row in df_noisy_query[df_noisy_query['cod_noise_kind']==noise_kind].iterrows():
          cod_original_query = row["cod_original_query"]
          idcg10 = dict_val_idcg10[cod_original_query]
          query_text = row["text"]

          # calculating dcg10 for query
          dcg10 = 0
          qtd_judment_assumed_zero_relevance = 0

          query_busca = Query(query_text)
          hits = searcher.search(query_busca.text, k=10)
          doctos_returned = hits_to_texts(hits)

          for i, doc in enumerate(doctos_returned):
              if i >= 10:
                  raise 'Error: more than 10 retrieved!'
              docid = doc.metadata["docid"]

              if (cod_original_query, docid) not in dict_judment:
                  print(f'Query and passage_id not in judment:{(cod_original_query, docid)}. Assumed zero relevance. ')
                  qtd_judment_assumed_zero_relevance += 1
              eval = dict_judment.get((cod_original_query, docid), 0)

              dcg10 += (2**int(eval)-1) / math.log2(i+2)
              # calculate ndcg10 for query
          ndcg10 = dcg10 / idcg10
          # print(f"query {cod_original_query} has dcg10 {dcg10} ndcg10 {ndcg10} for idcg10 {idcg10} ")


          calculated_metric['cod_original_query'].append(cod_original_query)
          calculated_metric['dcg10'].append(dcg10)
          calculated_metric['ndcg10'].append(ndcg10)
          calculated_metric['qtd_judment_assumed_zero_relevance'].append(qtd_judment_assumed_zero_relevance)
      # print(calculated_metric)
      util_bd_pandas.save_calculated_metric(calculated_metric, cod_search_context=3, cod_noise_kind=noise_kind)
# Out:
# Loaded len: 11386 judments; judment[0] ((23849, '1020327'), 2, 'highly relevant')
# Query and passage_id not in judment:(1121353, '8083913'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5300162'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '3541849'). Assumed zero relevance.
# saving calculated metric cod_search_context?3, cod_noise_kind:0
# Query and passage_id not in judment:(1121353, '8083913'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5300162'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '3541849'). Assumed zero relevance.
# saving calculated metric cod_search_context?3, cod_noise_kind:1
# Query and passage_id not in judment:(1121353, '8083913'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5300162'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '3541849'). Assumed zero relevance.
# saving calculated metric cod_search_context?3, cod_noise_kind:2
# Query and passage_id not in judment:(1121353, '8083913'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5300162'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '3541849'). Assumed zero relevance.
# saving calculated metric cod_search_context?3, cod_noise_kind:3
# Query and passage_id not in judment:(23849, '8769995'). Assumed zero relevance.
# Query and passage_id not in judment:(42255, '5549175'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '6180506'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4195059'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4371088'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '6977842'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4635855'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4574420'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '7823062'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '7998791'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '6753191'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '5323387'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '3672136'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '5490903'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '3487762'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '4391107'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '6699898'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '1193877'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '4050698'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '6180434'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '775468'). Assumed zero relevance.
# Query and passage_id not in judment:(156498, '3234911'). Assumed zero relevance.
# Query and passage_id not in judment:(156498, '8284851'). Assumed zero relevance.
# Query and passage_id not in judment:(156498, '3944738'). Assumed zero relevance.
# Query and passage_id not in judment:(156498, '6804478'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '6252711'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '1479804'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '6819404'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '6171146'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '6171142'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '5839768'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '6028156'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '8824698'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '5839767'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '8416228'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '7411856'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '7490889'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '6842100'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '4129657'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '3815318'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '2259742'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '3550293'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '1744752'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '5210319'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '5527853'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '641849'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '1744754'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '8504921'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '1893014'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '6715712'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '6104291'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '6104292'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '1147809'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '1147811'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '1147810'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '5095701'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '5095702'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '1041939'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '6796749'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '6759238'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '6688284'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '8145658'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '8290074'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '1939820'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '1856105'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '1939819'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '6824065'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '4086689'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '3074064'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '5490903'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '3487762'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '4391107'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '6699898'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '4050698'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '6180434'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '775468'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '3058146'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '8177315'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '4624755'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '5920064'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '5488572'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '5920066'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '8544395'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '4993951'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '5733130'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '7030351'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8083913'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '3467791'). Assumed zero relevance.
# saving calculated metric cod_search_context?3, cod_noise_kind:4
# Query and passage_id not in judment:(23849, '312646'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '6716844'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '8804496'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '34862'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '2769575'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '1836597'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '1256320'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '6879333'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '278662'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '3519736'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '8773687'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '5181839'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4195059'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4371088'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '6977842'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4635855'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4574420'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '7823062'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '7998791'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '6753191'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '5323387'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '8486367'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '5541539'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '6717195'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '6718985'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '4326254'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '5783037'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '3259571'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '2087378'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '5677369'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '7068640'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '5556800'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '4467784'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '6546374'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '6369620'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '2305518'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '8596354'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '5700585'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '6148794'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '1159947'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '5676116'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '5257858'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '7331783'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '713457'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '6581605'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '4866228'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '5707518'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '6016981'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '4129657'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '3815318'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '2259742'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '3550293'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '2369662'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '4894013'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '642397'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '270635'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '3121997'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '416002'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '2223012'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '237074'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '5304249'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '3122000'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '1210199'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '6805838'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '3074064'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3431861'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '4562029'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '7270941'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '7270940'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '4562034'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3708481'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '5915054'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '553180'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2540328'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '365861'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '1297032'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '7286317'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '6914894'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '5033381'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '3562314'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '5786130'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '5507719'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '7813300'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '5056645'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '2812921'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '4368659'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '2769054'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '7758785'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '3245659'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '8801997'). Assumed zero relevance.
# Query and passage_id not in judment:(1064670, '8030722'). Assumed zero relevance.
# Query and passage_id not in judment:(1064670, '2389809'). Assumed zero relevance.
# Query and passage_id not in judment:(1064670, '4853438'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '1400781'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8266790'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8254975'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8266789'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '5715055'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8189032'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '3136702'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8512413'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '7896538'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '8198585'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8083913'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '3541849'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8436349'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '4147307'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '6605205'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '825018'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '480905'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '7829698'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '7579917'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '480906'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '3070475'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '6605204'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '3227497'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '5906401'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '5086701'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '7171127'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '2622214'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '7341267'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '4039048'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '527286'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '6408377'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '5338924'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '6182713'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '1889280'). Assumed zero relevance.
# saving calculated metric cod_search_context?3, cod_noise_kind:5
# Query and passage_id not in judment:(23849, '312646'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '6716844'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '8804496'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '34862'). Assumed zero relevance.
# Query and passage_id not in judment:(42255, '5550456'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '1325092'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '7330184'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '6698946'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '6764673'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4195059'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4371088'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '6977842'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4635855'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4574420'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '7823062'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '7998791'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '6753191'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '5323387'). Assumed zero relevance.
# Query and passage_id not in judment:(141630, '1333838'). Assumed zero relevance.
# Query and passage_id not in judment:(141630, '7985123'). Assumed zero relevance.
# Query and passage_id not in judment:(156498, '8314103'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '86201'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '5585654'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '5556800'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '7450542'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '5677369'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '4211509'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '795390'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '1420284'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '7518750'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '7518746'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '7908225'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '8243793'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '5580302'). Assumed zero relevance.
# Query and passage_id not in judment:(330975, '7086788'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '4246422'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '3272391'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '3074898'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '3074899'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1442273'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '3908740'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '5883282'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '5834062'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '5595397'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '5905416'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '855933'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '349019'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '5915302'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '3423595'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '1957244'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '3310406'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '3367631'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '2737045'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3058085'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '6809641'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '8113059'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3922442'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '842934'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '8013626'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '8086096'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '4651212'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '1606419'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '7727999'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '1183908'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '3949623'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '8813137'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '7655935'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '7693496'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '6246561'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '4086689'). Assumed zero relevance.
# Query and passage_id not in judment:(940547, '4576505'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '4886382'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '2968049'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '2968044'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '7738276'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '2568499'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '8739265'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '49594'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3431861'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3158186'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '553180'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2540328'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '365861'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '1297032'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '7286317'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '6914894'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '5033381'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '3562314'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '5786130'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '5507719'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '3581772'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '3226775'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '3851277'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '4382120'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '4946657'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '4513249'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '4661916'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '6733197'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '1340141'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '7126494'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '728924'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '3266158'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '7131862'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '2765753'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '2918517'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '1894390'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8083913'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '3541849'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8436349'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5540042'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '371196'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '42124'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '5407363'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '8070678'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '1830774'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '7914595'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '4685777'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '798219'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '2600528'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '493579'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '4535907'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '6950258'). Assumed zero relevance.
# Query and passage_id not in judment:(1136043, '4109676'). Assumed zero relevance.
# Query and passage_id not in judment:(1136043, '912815'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '1500783'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '1500784'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '5822427'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '7087324'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '1049293'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '3551290'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '2165357'). Assumed zero relevance.
# Query and passage_id not in judment:(1136962, '5167251'). Assumed zero relevance.
# saving calculated metric cod_search_context?3, cod_noise_kind:6
# Query and passage_id not in judment:(23849, '2183977'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '7120002'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '2039331'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '2769575'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '1836597'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '1256320'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '6879333'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '278662'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '8205033'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '8205030'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '1740480'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '8205031'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '962550'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '4755624'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '1136340'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '1789231'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '5052006'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '269343'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '1136339'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3172369'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3134353'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '1538998'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '8491931'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '2223012'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '8145187'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '760192'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '416002'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '3121997'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '7140321'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '1117058'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '2951753'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '2360561'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '4331302'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '8461924'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '4752697'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '8428568'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '7001030'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '7457595'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '8794225'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '8794229'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '902708'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '6968028'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '1674264'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '4975431'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '68773'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '3702108'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '8051975'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '7450944'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '8757789'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '8078962'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '8649866'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '1183908'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '2463787'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '2861551'). Assumed zero relevance.
# Query and passage_id not in judment:(1030303, '5704775'). Assumed zero relevance.
# Query and passage_id not in judment:(1030303, '7242370'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '1106582'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '591524'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '2192513'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '3399979'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '1828636'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '5039920'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '3399981'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '5297929'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '5283414'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '6090006'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '459368'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '561629'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '2879392'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '2247468'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '3985265'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '3985261'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '7161596'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '6861855'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '7161593'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '2036754'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '648995'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '8297744'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '7640868'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '6976663'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '595120'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '8272454'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '4902731'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '2411392'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '146861'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '6815352'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8083913'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5300162'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '3541849'). Assumed zero relevance.
# saving calculated metric cod_search_context?3, cod_noise_kind:7
# Query and passage_id not in judment:(23849, '2039331'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '2174853'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '3828999'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '4190254'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '4190253'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '3829000'). Assumed zero relevance.
# Query and passage_id not in judment:(42255, '5549175'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '1325092'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '2863188'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '6091557'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '1818896'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '4544249'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '18103'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '7137013'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '7490889'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '4898107'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1284210'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '4898101'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '976267'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '7122511'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3262422'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '819189'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '3262422'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '3806476'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '6246561'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '4086689'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '6246557'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '2532051'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '7122511'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '6418813'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '7183454'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8083913'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5300162'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8436349'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5540042'). Assumed zero relevance.
# Query and passage_id not in judment:(1127540, '1818896'). Assumed zero relevance.
# Query and passage_id not in judment:(1127540, '4544249'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '8633190'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '6726501'). Assumed zero relevance.
# Query and passage_id not in judment:(336901, '560666'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '553180'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2540328'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '365861'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '1297032'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '7286317'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '6914894'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '5033381'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '3562314'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '5786130'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '5507719'). Assumed zero relevance.
# saving calculated metric cod_search_context?3, cod_noise_kind:8

# %% [markdown]
# ## Rank BM25 (1000 melhores ranks)

# %%
import json
from pygaggle.rerank.base import Query, Text
from pygaggle.rerank.base import hits_to_texts

# %%
  _, dict_val_idcg10 = util_bd_pandas.read_df_original_query()
  df_noisy_query = util_bd_pandas.read_df_noisy_query()
  dict_judment, _ = util_bd_pandas.load_judment()

  # Calculate dcg10 and ndcg10 of noisy queries
  for noise_kind in df_noisy_query['cod_noise_kind'].unique():
      calculated_metric = {'cod_original_query':[],'dcg10':[],'ndcg10':[], 'qtd_judment_assumed_zero_relevance':[]}
      for index, row in df_noisy_query[df_noisy_query['cod_noise_kind']==noise_kind].iterrows():
          cod_original_query = row["cod_original_query"]
          idcg10 = dict_val_idcg10[cod_original_query]
          query_text = row["text"]

          # calculating dcg10 for query
          dcg10 = 0
          qtd_judment_assumed_zero_relevance = 0

          query_busca = Query(query_text)
          hits = searcher.search(query_busca.text, k=1000)

          doctos_returned_bm25 = hits_to_texts(hits)

          doctos_returned = reranker.rerank(query_busca, doctos_returned_bm25)

          for i, doc in enumerate(doctos_returned[:10]):
              if i >= 10:
                  raise 'Error: more than 10 retrieved!'
              docid = doc.metadata["docid"]

              if (cod_original_query, docid) not in dict_judment:
                  print(f'Query and passage_id not in judment:{(cod_original_query, docid)}. Assumed zero relevance. ')
                  qtd_judment_assumed_zero_relevance += 1
              eval = dict_judment.get((cod_original_query, docid), 0)

              dcg10 += (2**int(eval)-1) / math.log2(i+2)
              # calculate ndcg10 for query
          ndcg10 = dcg10 / idcg10
          # print(f"query {cod_original_query} has dcg10 {dcg10} ndcg10 {ndcg10} for idcg10 {idcg10} ")


          calculated_metric['cod_original_query'].append(cod_original_query)
          calculated_metric['dcg10'].append(dcg10)
          calculated_metric['ndcg10'].append(ndcg10)
          calculated_metric['qtd_judment_assumed_zero_relevance'].append(qtd_judment_assumed_zero_relevance)
      util_bd_pandas.save_calculated_metric(calculated_metric, cod_search_context=1, cod_noise_kind=noise_kind)    
      print(f" Done for noise_kind: {noise_kind}")
# Out:
# Loaded len: 11386 judments; judment[0] ((23849, '1020327'), 2, 'highly relevant')
# Query and passage_id not in judment:(324585, '1514877'). Assumed zero relevance.
# Query and passage_id not in judment:(336901, '2261724'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '3340708'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8643791'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '5272210'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '7238888'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8684415'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '643775'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '2213823'). Assumed zero relevance.
# saving calculated metric cod_search_context?1, cod_noise_kind:0
#  Done for noise_kind: 0
# Query and passage_id not in judment:(23849, '4806514'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '1514877'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '5257858'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '5975275'). Assumed zero relevance.
# Query and passage_id not in judment:(336901, '2261724'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '2328883'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '844997'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '1861076'). Assumed zero relevance.
# Query and passage_id not in judment:(1030303, '3880502'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '5272210'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '7238888'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8684415'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '643775'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '7344843'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '2698317'). Assumed zero relevance.
# saving calculated metric cod_search_context?1, cod_noise_kind:1
#  Done for noise_kind: 1
# Query and passage_id not in judment:(23849, '4806514'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '1514877'). Assumed zero relevance.
# Query and passage_id not in judment:(336901, '3753992'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '2328883'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '3340708'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '7714171'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '5272210'). Assumed zero relevance.
# Query and passage_id not in judment:(1113256, '6537674'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '6379159'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8684415'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '5145967'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '2698317'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '569543'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '8307660'). Assumed zero relevance.
# saving calculated metric cod_search_context?1, cod_noise_kind:2
#  Done for noise_kind: 2
# Query and passage_id not in judment:(67316, '5519660'). Assumed zero relevance.
# Query and passage_id not in judment:(336901, '7819234'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '5605959'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '1807676'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '7714171'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '4384327'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8643791'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '4224836'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '3009938'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '7238888'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8684415'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '6379159'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5504217'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '7384403'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '1141681'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '824922'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '569543'). Assumed zero relevance.
# saving calculated metric cod_search_context?1, cod_noise_kind:3
#  Done for noise_kind: 3
# Query and passage_id not in judment:(23849, '1304847'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '1594079'). Assumed zero relevance.
# Query and passage_id not in judment:(23849, '8264389'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '5678487'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '6091469'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '7111673'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '6507744'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '3519736'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '2273934'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '7375817'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4574420'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4525887'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4660330'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '5887008'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '637718'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '637713'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '5802973'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4525890'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '5997548'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '4489534'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '4935191'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '1193877'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '2344062'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '4578485'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '2344063'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '6225668'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '1124681'). Assumed zero relevance.
# Query and passage_id not in judment:(121171, '5833611'). Assumed zero relevance.
# Query and passage_id not in judment:(156498, '3929551'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '3281200'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '3616027'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '5507046'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '4229483'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '5252895'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '6643673'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '182040'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '2599922'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '3352814'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '2027911'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '7411856'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '5975275'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '5517230'). Assumed zero relevance.
# Query and passage_id not in judment:(336901, '519896'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1139946'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1691213'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '6154974'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '7166011'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '4631848'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '3421043'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '1567779'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '6283884'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '4631847'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '7227325'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '8181047'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '2806299'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '1893010'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '3110654'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '8718822'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '5959308'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '7755045'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '8300392'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '1531823'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '3870126'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '7189013'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '1264656'). Assumed zero relevance.
# Query and passage_id not in judment:(583468, '4433281'). Assumed zero relevance.
# Query and passage_id not in judment:(1030303, '3880502'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '8787049'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '2664987'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '5725262'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '5997548'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '4489534'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '4935191'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '4578485'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '2344063'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '6225668'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '1124681'). Assumed zero relevance.
# Query and passage_id not in judment:(1105792, '5833611'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '3276824'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '970167'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '5838049'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '5405890'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '8585468'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '4126033'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '430216'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '1588765'). Assumed zero relevance.
# Query and passage_id not in judment:(1106979, '8177315'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '8377856'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '5272210'). Assumed zero relevance.
# Query and passage_id not in judment:(1113256, '6537674'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '7238888'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8684415'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5956717'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '6379159'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '5061881'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '2698317'). Assumed zero relevance.
# saving calculated metric cod_search_context?1, cod_noise_kind:4
#  Done for noise_kind: 4
# Query and passage_id not in judment:(47210, '2769575'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '5563743'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '7367874'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '7878891'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '1764822'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '1839671'). Assumed zero relevance.
# Query and passage_id not in judment:(47210, '4748993'). Assumed zero relevance.
# Query and passage_id not in judment:(67316, '2666420'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '7375817'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4574420'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4525887'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4660330'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '5887008'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '637718'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '637713'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '5802973'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4525890'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '7169068'). Assumed zero relevance.
# Query and passage_id not in judment:(169208, '4694328'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '5453683'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '2591350'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '7300117'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '6898664'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '1991578'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '1991580'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '2194313'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '6506296'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '4952096'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1139946'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1691213'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '6154974'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '7166011'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '3340708'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '3264636'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '381931'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '1699264'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '8517849'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '4832975'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '1125916'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '1389025'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '8106959'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '5999763'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '3703938'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '5758395'). Assumed zero relevance.
# Query and passage_id not in judment:(940547, '4652486'). Assumed zero relevance.
# Query and passage_id not in judment:(940547, '5072883'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3874556'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '4562029'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '5008806'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3694036'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '4562034'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '4357743'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3694043'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '4716493'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '4358891'). Assumed zero relevance.
# Query and passage_id not in judment:(1030303, '1292819'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2651671'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2007580'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '3407762'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '462284'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '8296966'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2007577'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '1297032'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '721533'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2041529'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '933791'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '5344444'). Assumed zero relevance.
# Query and passage_id not in judment:(1064670, '8724181'). Assumed zero relevance.
# Query and passage_id not in judment:(1064670, '3121310'). Assumed zero relevance.
# Query and passage_id not in judment:(1064670, '4313091'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '4062418'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '7115328'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '378711'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '7177888'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8254975'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '3960291'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '8423575'). Assumed zero relevance.
# Query and passage_id not in judment:(1113256, '6537674'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '765784'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '5956717'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '643775'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '3405771'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '3688128'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '2930347'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '5668181'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '3926205'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '569543'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '7740550'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '4388949'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '2649453'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '7740553'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '7740552'). Assumed zero relevance.
# Query and passage_id not in judment:(1132532, '8600388'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '3314122'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '5932372'). Assumed zero relevance.
# Query and passage_id not in judment:(1133579, '8135531'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '4210771'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '2330115'). Assumed zero relevance.
# saving calculated metric cod_search_context?1, cod_noise_kind:5
#  Done for noise_kind: 5
# Query and passage_id not in judment:(67316, '308680'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '7375817'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4574420'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4525887'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4660330'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '5887008'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '637718'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '637713'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '5802973'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '4525890'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '1005914'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '795390'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '7427748'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '3777932'). Assumed zero relevance.
# Query and passage_id not in judment:(258062, '5485328'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '6007047'). Assumed zero relevance.
# Query and passage_id not in judment:(332593, '5257859'). Assumed zero relevance.
# Query and passage_id not in judment:(336901, '2261724'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1335506'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '604226'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1857042'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '5358593'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1326100'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '5358588'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '844997'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1032415'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1689725'). Assumed zero relevance.
# Query and passage_id not in judment:(405163, '3340708'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '6356122'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '886754'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '8152618'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '5106749'). Assumed zero relevance.
# Query and passage_id not in judment:(555530, '7337502'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '8521270'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '8521269'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '3839640'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '218507'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '300929'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '1226402'). Assumed zero relevance.
# Query and passage_id not in judment:(640502, '3551383'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '5558888'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '280310'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '4388874'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '7291987'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '5837057'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '7914595'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3459646'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '5381100'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '8151708'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '1397094'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '5758395'). Assumed zero relevance.
# Query and passage_id not in judment:(877809, '7714171'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '6818268'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '5781231'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '8649174'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '5784912'). Assumed zero relevance.
# Query and passage_id not in judment:(914916, '7407146'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3616636'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3878046'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3948379'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3964402'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '67849'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3086619'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '4491885'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3694036'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '3069053'). Assumed zero relevance.
# Query and passage_id not in judment:(997622, '5987841'). Assumed zero relevance.
# Query and passage_id not in judment:(1030303, '1305519'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2651671'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2007580'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '3407762'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '462284'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '8296966'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2007577'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '1297032'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '721533'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2041529'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '933791'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '5725262'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '4125386'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8733630'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '4382120'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '7183070'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '3321887'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '5083333'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '6771497'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8328523'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '8441435'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '5418070'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '2946793'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '2581464'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '849'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '1911568'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '3943399'). Assumed zero relevance.
# Query and passage_id not in judment:(1109707, '4862297'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '5272210'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '8390252'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '3900997'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '1642862'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '382378'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '6198774'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '7905905'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '2474382'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8684415'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '3663574'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8838156'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '2799568'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '6783847'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '6960778'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '4350046'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '7074975'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '5962406'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '7254420'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '6115757'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '842312'). Assumed zero relevance.
# Query and passage_id not in judment:(1122767, '6669700'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '824922'). Assumed zero relevance.
# Query and passage_id not in judment:(1136047, '2995922'). Assumed zero relevance.
# saving calculated metric cod_search_context?1, cod_noise_kind:6
#  Done for noise_kind: 6
# Query and passage_id not in judment:(42255, '1606219'). Assumed zero relevance.
# Query and passage_id not in judment:(42255, '1606220'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '8205030'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '6417877'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '8205033'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '1740479'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '5174911'). Assumed zero relevance.
# Query and passage_id not in judment:(135802, '8073708'). Assumed zero relevance.
# Query and passage_id not in judment:(324585, '1514877'). Assumed zero relevance.
# Query and passage_id not in judment:(336901, '2261724'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '844997'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3650851'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '8706328'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3650852'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '4721159'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '6640863'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3650856'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3495921'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3169327'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '3584158'). Assumed zero relevance.
# Query and passage_id not in judment:(673670, '6127435'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '3264640'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '928334'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '381936'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '1125916'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '5008056'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '781518'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '1389025'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '2610149'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '5999763'). Assumed zero relevance.
# Query and passage_id not in judment:(701453, '7494104'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '3028760'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '8794229'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '6968028'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '8794225'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '1563061'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '8428568'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '4752698'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '6162884'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '7139412'). Assumed zero relevance.
# Query and passage_id not in judment:(730539, '4879518'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '8484177'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '7512576'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '1431776'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '2663777'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '4238479'). Assumed zero relevance.
# Query and passage_id not in judment:(911232, '4517905'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '7338335'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '7338333'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '5119425'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '108845'). Assumed zero relevance.
# Query and passage_id not in judment:(1043135, '2954595'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '8643791'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '5272210'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '6988371'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '1355596'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '5349614'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '3982694'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '2605259'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '1779762'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '6384850'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '8002171'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '6384855'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '1967193'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '595117'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '679111'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '2411398'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '595114'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '1645709'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '289867'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '1645707'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '679114'). Assumed zero relevance.
# Query and passage_id not in judment:(1116380, '8271561'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '6379159'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8684415'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '6307464'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '4344765'). Assumed zero relevance.
# Query and passage_id not in judment:(1131069, '4344761'). Assumed zero relevance.
# saving calculated metric cod_search_context?1, cod_noise_kind:7
#  Done for noise_kind: 7
# Query and passage_id not in judment:(67316, '3557361'). Assumed zero relevance.
# Query and passage_id not in judment:(118440, '2605334'). Assumed zero relevance.
# Query and passage_id not in judment:(174463, '1750798'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '4249586'). Assumed zero relevance.
# Query and passage_id not in judment:(390360, '1139946'). Assumed zero relevance.
# Query and passage_id not in judment:(938400, '3424110'). Assumed zero relevance.
# Query and passage_id not in judment:(940547, '5831709'). Assumed zero relevance.
# Query and passage_id not in judment:(1108651, '815596'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '5272210'). Assumed zero relevance.
# Query and passage_id not in judment:(1110678, '7896538'). Assumed zero relevance.
# Query and passage_id not in judment:(1115210, '7238888'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '8684415'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '643775'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '6379159'). Assumed zero relevance.
# Query and passage_id not in judment:(1121353, '7344843'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2651671'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2124626'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2041529'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2500672'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '2123923'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '3645643'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '8744793'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '1913071'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '7779272'). Assumed zero relevance.
# Query and passage_id not in judment:(1037496, '1297032'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '3562990'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '3694758'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '3562989'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '4878563'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '3694752'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '4894286'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '2894408'). Assumed zero relevance.
# Query and passage_id not in judment:(1051399, '5150674'). Assumed zero relevance.
# saving calculated metric cod_search_context?1, cod_noise_kind:8
#  Done for noise_kind: 8

# %%
from google.colab import files

# %%
files.download( "data/tab_calculated_metric.csv" )
